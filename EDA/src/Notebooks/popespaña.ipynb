# %%
import pandas as pd, numpy as np, re

# %%
españa = pd.read_csv('data\\regiones.csv')

# %%
españa
# Out:
#                           C.A.       2013       2014       2015       2016  \
# 0                      Galicia  2.761.989  2.747.226  2.734.656  2.720.102
# 1       Principado de Asturias  1.067.797  1.058.975  1.049.875  1.040.925
# 2                    Cantabria    590.036    587.682    585.359    582.504
# 3                   País Vasco  2.177.006  2.167.166  2.165.100  2.164.066
# 4   Comunidad Foral de Navarra    638.948    636.450    636.402    637.486
# 5                     La Rioja    318.647    315.223    313.569    312.810
# 6                       Aragón  1.338.316  1.331.301  1.326.403  1.318.571
# 7          Comunidad de Madrid  6.414.620  6.378.297  6.385.298  6.424.275
# 8              Castilla y León  2.518.560  2.495.689  2.478.079  2.454.454
# 9           Castilla-la Mancha  2.094.406  2.075.197  2.062.767  2.048.900
# 10                    Cataluña  7.480.921  7.416.237  7.396.991  7.408.290
# ...

# %%
españa.to_csv('..\Aguas\data\españa.csv')
